# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn import metrics 

df=pd.read_csv(r"C:\Users\Amin\Downloads\USA_Housing.csv") 

x = df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms', 
        'Avg. Area Number of Bedrooms', 'Area Population']]
y= df[['Price']] 

x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.3, 
                                                  random_state=101)  
lm=LinearRegression() 
lm.fit(x_train, y_train) 

predictions=lm.predict(x_test) 

print("r**2 score: ", metrics.r2_score(y_test, predictions)) 
print("MAE: ", metrics.mean_absolute_error(y_test, predictions)) 
print("RMSE: ", np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# r**2 score:  0.9185060945363626
# MAE:  81257.5579585593
# RMSE:  100842.0823163503

# %%
lm.predict([[70000, 6, 7, 4, 30000]])
# Out:
# C:\Users\Amin\Downloads\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[1175056.87780789]])
